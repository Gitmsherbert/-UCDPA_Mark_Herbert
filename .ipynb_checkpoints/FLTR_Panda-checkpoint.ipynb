# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # Import matplotlib.pyplot as plt

# Read the CSV file
df_FLTR = pd.read_csv('FLTR.L.csv', parse_dates=['Date'], index_col='Date')

# data_FLTR = df_FLTR[[ 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] --no longer need this as the above line reads in column names

df_FLTR.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-02  8659.903320  8817.266602  8654.985352  8753.337891  8096.356445
# 2018-01-03  8694.326172  8733.666992  8620.562500  8625.480469  7978.095215
# 2018-01-04  8630.397461  8654.985352  8536.962891  8615.644531  7968.997070
# 2018-01-05  8659.903320  8738.584961  8630.397461  8723.832031  8069.064453
# 2018-01-08  8556.633789  8650.068359  8492.705078  8650.068359  8000.837891
#
#             Volume
# Date
# 2018-01-02  116553
# 2018-01-03   73075
# 2018-01-04   93162
# 2018-01-05  195428
# 2018-01-08  149571

# %%
df_FLTR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1304 entries, 2018-01-02 to 2023-02-28
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Open            1304 non-null   float64
#  1   High            1304 non-null   float64
#  2   Low             1304 non-null   float64
#  3   Close           1304 non-null   float64
#  4   Adj Close       1304 non-null   float64
#  5   Volume          1304 non-null   int64
#  6   Month           1304 non-null   int64
#  7   Close_by_Month  1304 non-null   float64
# dtypes: float64(6), int64(2)
# memory usage: 124.0 KB

# %%
print(df_FLTR.loc['2018-01-03'])
# Out:
# Open          8694.326172
# High          8733.666992
# Low           8620.562500
# Close         8625.480469
# Adj Close     7978.095215
# Volume       73075.000000
# Name: 2018-01-03 00:00:00, dtype: float64

# %%
# drop duplicate rows
df_FLTR.deduplicated = df_FLTR.drop_duplicates()

print(df_FLTR.deduplicated)
# Out:
#                     Open          High           Low         Close  \
# Date
# 2018-01-02   8659.903320   8817.266602   8654.985352   8753.337891
# 2018-01-03   8694.326172   8733.666992   8620.562500   8625.480469
# 2018-01-04   8630.397461   8654.985352   8536.962891   8615.644531
# 2018-01-05   8659.903320   8738.584961   8630.397461   8723.832031
# 2018-01-08   8556.633789   8650.068359   8492.705078   8650.068359
# ...                  ...           ...           ...           ...
# 2023-02-22  13875.000000  13875.000000  13625.000000  13680.000000
# 2023-02-23  13815.000000  13925.000000  13580.000000  13925.000000
# 2023-02-24  13800.000000  13875.000000  13035.000000  13065.000000
# 2023-02-27  13110.000000  13540.000000  13110.000000  13465.000000
# 2023-02-28  13465.000000  13465.000000  13250.000000  13335.000000
#
#                Adj Close   Volume
# Date
# 2018-01-02   8096.356445   116553
# 2018-01-03   7978.095215    73075
# 2018-01-04   7968.997070    93162
# 2018-01-05   8069.064453   195428
# 2018-01-08   8000.837891   149571
# ...                  ...      ...
# 2023-02-22  13680.000000  1350026
# 2023-02-23  13925.000000   301007
# 2023-02-24  13065.000000   394355
# 2023-02-27  13465.000000   809545
# 2023-02-28  13335.000000   931226
#
# [1304 rows x 6 columns]

# %%
print(df_FLTR.index.min())
print(df_FLTR.index.max()) #min and max dates
# Out:
# 2018-01-02 00:00:00
# 2023-02-28 00:00:00

# %%
df_FLTR.isnull() #checking for any null values in the data
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2018-01-02  False  False  False  False      False   False
# 2018-01-03  False  False  False  False      False   False
# 2018-01-04  False  False  False  False      False   False
# 2018-01-05  False  False  False  False      False   False
# 2018-01-08  False  False  False  False      False   False
# ...           ...    ...    ...    ...        ...     ...
# 2023-02-22  False  False  False  False      False   False
# 2023-02-23  False  False  False  False      False   False
# 2023-02-24  False  False  False  False      False   False
# 2023-02-27  False  False  False  False      False   False
# 2023-02-28  False  False  False  False      False   False
#
# [1304 rows x 6 columns]

# %%
#no null values in the dataset

# %%
grouped_df_FLTR = df_FLTR.groupby('Close').mean()#this is wrong?
print(grouped_df_FLTR)
# Out:
#                       Open          High           Low     Adj Close  \
# Close
# 81.739998        82.919998     83.379997     79.900002     81.739998
# 5421.168457    5454.607910   5729.994141   5370.025391   5324.683105
# 5433.954102    5527.388672   5527.388672   5301.178711   5170.020020
# 5499.850098    5570.663574   5570.663574   5462.476074   5350.215332
# 5502.800293    5586.399902   5610.987793   5443.789063   5235.522461
# ...                    ...           ...           ...           ...
# 16770.000000  17130.000000  17130.000000  16620.000000  16770.000000
# 16830.000000  16680.000000  16915.000000  16455.000000  16830.000000
# 16875.000000  16555.000000  17030.000000  16475.000000  16875.000000
# 16890.000000  16850.000000  19680.800781  16390.000000  16890.000000
# 16915.000000  16755.000000  17005.000000  16605.000000  16915.000000
#
#                  Volume
# Close
# 81.739998     1677995.0
# 5421.168457    621366.0
# 5433.954102    427535.0
# 5499.850098    114170.0
# 5502.800293    260193.0
# ...                 ...
# 16770.000000   492746.0
# 16830.000000   340165.0
# 16875.000000   979599.0
# 16890.000000  4015349.0
# 16915.000000   427716.0
#
# [1059 rows x 5 columns]

# %%
df_FLTR[['Open', 'High', 'Low', 'Close']].resample('Q').min() #resample with the min prices by each quarter
# Out:
#                 Open      High       Low     Close
# Date
# 2018-03-31   7071.52   7140.36   6958.41   7037.09
# 2018-06-30   6668.27   6786.30   6569.92   6687.94
# 2018-09-30   6619.10   6638.77   6383.05   6383.05
# 2018-12-31   5906.04   5969.97   5901.13   5910.96
# 2019-03-31   5443.79   5527.39   5301.18   5433.95
# 2019-06-30   5460.51   5539.19   5442.81   5499.85
# 2019-09-30   5840.15   6054.56   5840.15   6032.92
# 2019-12-31   7342.97   7401.98   7291.83   7346.90
# 2020-03-31   5454.61   5729.99   4921.54   5421.17
# 2020-06-30   6709.58   6994.80   6571.89   6721.38
# 2020-09-30  10475.00  10670.00  10422.10  10515.00
# 2020-12-31  12165.00  12280.00  11950.00  12245.00
# 2021-03-31  13390.00  13825.00  13380.00  13625.00
# 2021-06-30  12335.00  12475.00  12085.00  12230.00
# 2021-09-30  11950.00  12055.00  11700.00  11860.00
# 2021-12-31  10095.00  10310.00   9912.00  10030.00
# 2022-03-31   7626.00   8260.00   7600.00   8000.00
# 2022-06-30     82.92     83.38     79.90     81.74
# 2022-09-30   7590.00   7676.00   7340.00   7614.00
# 2022-12-31   9710.00   9908.00   9680.00   9694.00
# 2023-03-31  11405.00  11775.00  11375.00  11450.00

# %%
df_FLTR = df_FLTR.round(2) #this rounds all the numeric figures to 2 decimal places.

# %%
df_FLTR.dtypes #showing the data types in each column
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df_FLTR[['Open', 'High', 'Low', 'Close']].resample('M').mean() #  #Resample to monthly frequency and take the mean and some further analysis using the datetime index
# Out:
#                     Open          High           Low         Close
# Date
# 2018-01-31   8325.057727   8391.894545   8231.847273   8302.706364
# 2018-02-28   8084.050500   8169.126500   8045.939000   8123.147000
# 2018-03-31   7619.712857   7672.870476   7503.562381   7579.434286
# 2018-04-30   7007.342500   7072.993000   6949.805000   7009.062500
# 2018-05-31   7779.650952   7974.715714   7697.456667   7883.625238
# ...                  ...           ...           ...           ...
# 2022-10-31  10569.761905  10816.980952  10431.952381  10655.714286
# 2022-11-30  11599.545455  11796.136364  11447.500000  11621.363636
# 2022-12-31  11772.750000  11879.500000  11633.000000  11717.500000
# 2023-01-31  12325.238095  12495.575714  12186.549048  12355.476190
# 2023-02-28  13200.000000  13361.508500  12981.250000  13179.250000
#
# [62 rows x 4 columns]

# %%
df_FLTR.isnull() #checking for any null values in the data
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2018-01-02  False  False  False  False      False   False
# 2018-01-03  False  False  False  False      False   False
# 2018-01-04  False  False  False  False      False   False
# 2018-01-05  False  False  False  False      False   False
# 2018-01-08  False  False  False  False      False   False
# ...           ...    ...    ...    ...        ...     ...
# 2023-02-22  False  False  False  False      False   False
# 2023-02-23  False  False  False  False      False   False
# 2023-02-24  False  False  False  False      False   False
# 2023-02-27  False  False  False  False      False   False
# 2023-02-28  False  False  False  False      False   False
#
# [1304 rows x 6 columns]

# %%
df_FLTR.info
# Out:
# <bound method DataFrame.info of                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2018-01-02   8659.90   8817.27   8654.99   8753.34    8096.36   116553
# 2018-01-03   8694.33   8733.67   8620.56   8625.48    7978.10    73075
# 2018-01-04   8630.40   8654.99   8536.96   8615.64    7969.00    93162
# 2018-01-05   8659.90   8738.58   8630.40   8723.83    8069.06   195428
# 2018-01-08   8556.63   8650.07   8492.71   8650.07    8000.84   149571
# ...              ...       ...       ...       ...        ...      ...
# 2023-02-22  13875.00  13875.00  13625.00  13680.00   13680.00  1350026
# 2023-02-23  13815.00  13925.00  13580.00  13925.00   13925.00   301007
# 2023-02-24  13800.00  13875.00  13035.00  13065.00   13065.00   394355
# 2023-02-27  13110.00  13540.00  13110.00  13465.00   13465.00   809545
# 2023-02-28  13465.00  13465.00  13250.00  13335.00   13335.00   931226
#
# [1304 rows x 6 columns]>

# %%
print(df_FLTR[9:11])
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2018-01-15  8389.43  8409.11  8281.25  8389.43    7759.77  199689
# 2018-01-16  8399.27  8487.79  8271.41  8320.59    7696.09  131162

# %%
# Plot histogram of 'Volume' variable
plt.hist(df_FLTR['Volume'], bins=100, density=1) # I plyaed around with the bindwidth here with the number of bins and I also used the 'density' option to show the % of the data represented in that range
plt.xlabel('Volume')
plt.ylabel('Frequency (%)') #I also changed the label to show this now represents the % rather thsn count
plt.show()

# %%
# Plot histogram of 'Close' stock price variable
plt.hist(df_FLTR['Close'], bins=30) # I plyaed around with the bindwidth here but count was a much better identifier than frequency(%)
plt.xlabel('Volume')
plt.ylabel('Count')
plt.show()

# %%
# Calculate the price change
delta = df_FLTR['Close'].diff()

# Define the time window for RSI calculation
window_length = 14

# Calculate the gains and losses with exponential weighting
gain = delta.where(delta > 0, 0)
loss = -delta.where(delta < 0, 0)
avg_gain = gain.ewm(com=(window_length - 1), min_periods=window_length).mean()
avg_loss = loss.ewm(com=(window_length - 1), min_periods=window_length).mean()

# Calculate the relative strength
rs = avg_gain / avg_loss

# Calculate the RSI
rsi = 100 - (100 / (1 + rs))

# Add the RSI to the DataFrame
df_FLTR['rsi'] = rsi

# Visualize the RSI with matplotlib
df_FLTR['rsi'].plot()
plt.show()

# %%
df_FLTR[4:9]
# Out:
#                Open     High      Low    Close  Adj Close  Volume
# Date
# 2018-01-08  8556.63  8650.07  8492.71  8650.07    8000.84  149571
# 2018-01-09  8669.74  8714.00  8630.40  8654.99    8005.38  131328
# 2018-01-10  8620.56  8699.24  8281.25  8335.34    7709.73  182109
# 2018-01-11  8153.39  8320.59  8153.39  8266.50    7646.05  211819
# 2018-01-12  8251.74  8359.93  8207.48  8320.59    7696.09  198914

# %%
df_FLTR.describe()
# Out:
#                Open          High           Low         Close     Adj Close        Volume        Month  Close_by_Month
# count   1304.000000   1304.000000   1304.000000   1304.000000   1304.000000  1.304000e+03  1304.000000     1304.000000
# mean    9829.233115   9981.695741   9677.147565   9826.217119   9694.440091  4.509396e+05     6.370399     9826.217119
# std     2941.855284   2988.818444   2893.998009   2934.870495   3050.111673  4.076404e+05     3.502887      533.376893
# min       82.919998     83.379997     79.900002     81.739998     81.739998  3.007300e+04     1.000000     9045.294843
# 25%     7275.105591   7370.015503   7139.133911   7285.432373   6952.404297  2.255720e+05     3.000000     9354.402810
# 50%     9000.000000   9086.883789   8825.134765   8950.041992   8890.540039  3.494410e+05     6.000000    10125.706559
# 75%    12201.250000  12385.000000  12040.000000  12222.500000  12222.500000  5.602382e+05     9.000000    10251.691628
# max    17130.000000  19680.800781  16620.000000  16915.000000  16915.000000  5.769086e+06    12.000000    10627.503737

# %%
plt.plot(df_FLTR.index, df_FLTR['Close'], color='red')
plt.plot(df_FLTR.index, df_FLTR['Low'], color='yellow')
plt.plot(df_FLTR.index, df_FLTR['High'], color='green', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Trend of Closing Price')
plt.show()

# %%
#Bar plot showing the volume of trades over time
plt.bar(df.index, df['Volume'])
plt.xlabel('Date')
plt.ylabel('')
plt.title('Volume of Trades')
plt.show()

# %%
#Scatter plot showing relationship between the daily high and low prices
plt.scatter(df['High'], df['Low'])
plt.xlabel('Daily High')
plt.ylabel('Daily Low')
plt.title('Daily High vs Low')
plt.show()

# %%
#This code will create a two new columns into the df_FLTR df, called 'Month' and 'Close by Month' that contains the average price for each month.

df_FLTR['Month'] = df_FLTR.index.month
df_FLTR['Close_by_Month'] = df_FLTR['Close'].groupby(df_FLTR['Month']).transform('mean')
df_FLTR.sum('Close_by_Month')

#below is a boxplot 

df.boxplot(column='Close_by_Month')
plt.xlabel('')
plt.ylabel('Closing Price')
plt.title('Distribution of Closing Price by Month')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'Close_by_Month'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[165], line 5
#       3 df_FLTR['Month'] = df_FLTR.index.month
#       4 df_FLTR['Close_by_Month'] = df_FLTR['Close'].groupby(df_FLTR['Month']).transform('mean')
# ----> 5 df_FLTR.sum('Close_by_Month')
#       7 #below is a boxplot
#       9 df.boxplot(column='Close_by_Month')
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:11797, in NDFrame._add_numeric_operations.<locals>.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11777 @doc(
#   11778     _num_doc,
#   11779     desc="Return the sum of the values over the requested axis.\n\n"
#    (...)
#   11795     **kwargs,
#   11796 ):
# > 11797     return NDFrame.sum(
#   11798         self, axis, skipna, level, numeric_only, min_count, **kwargs
#   11799     )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:11501, in NDFrame.sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11492 def sum(
#   11493     self,
#   11494     axis: Axis | None = None,
#    (...)
#   11499     **kwargs,
#   11500 ):
# > 11501     return self._min_count_stat_function(
#   11502         "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   11503     )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:11483, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11467     warnings.warn(
#   11468         "Using the level keyword in DataFrame and Series aggregations is "
#   11469         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11472         stacklevel=find_stack_level(),
#   11473     )
#   11474     return self._agg_by_level(
#   11475         name,
#   11476         axis=axis,
#    (...)
#   11480         numeric_only=numeric_only,
#   11481     )
# > 11483 return self._reduce(
#   11484     func,
#   11485     name=name,
#   11486     axis=axis,
#   11487     skipna=skipna,
#   11488     numeric_only=numeric_only,
#   11489     min_count=min_count,
#   11490 )
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:10811, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10808         self = type(self)(mgr)
#   10810 # TODO: Make other agg func handle axis=None properly GH#21597
# > 10811 axis = self._get_axis_number(axis)
#   10812 labels = self._get_agg_axis(axis)
#   10813 assert axis in [0, 1]
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:556, in NDFrame._get_axis_number(cls, axis)
#     554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
# --> 556     raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named Close_by_Month for object type DataFrame

# %%
# Resample by month and sum the values in volume columns, this gives me an idea of volume over the time period

monthly_summary = df_FLTR['Volume'].resample('M').sum()

# Set Pandas display options - this allows us to see ALL output but should obviously be used sparingly with large datasets!
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.expand_frame_repr", False)

# Print the summary
print(monthly_summary[:5])
# Out:
# Date
# 2018-01-31    3792437
# 2018-02-28    4774158
# 2018-03-31    5026028
# 2018-04-30    3909727
# 2018-05-31    8228829
# Freq: M, Name: Volume, dtype: int64

# %%
#now the sum on a yearly basis as well as the mean (average) note 2023 is only partial

yearly_summary = df_FLTR['Volume'].resample('Y').sum()

print(yearly_summary)

yearly_summary = df_FLTR['Volume'].resample('Y').mean()

print(yearly_summary)
# Out:
# Date
# 2018-12-31     67576949
# 2019-12-31     84505070
# 2020-12-31    135130978
# 2021-12-31    113158952
# 2022-12-31    157448975
# 2023-12-31     30204351
# Freq: A-DEC, Name: Volume, dtype: int64
# Date
# 2018-12-31    267102.565217
# 2019-12-31    334012.134387
# 2020-12-31    532011.724409
# 2021-12-31    447268.584980
# 2022-12-31    629795.900000
# 2023-12-31    736691.487805
# Freq: A-DEC, Name: Volume, dtype: float64

# %%
#the mean funtion would be better suited to some of the other columns such as the Adjusted Close Price  

yearly_mean_summary = df_FLTR['Adj Close'].resample('Y').mean()

print(yearly_mean_summary)
# Out:
# Date
# 2018-12-31     6975.008221
# 2019-12-31     6554.333953
# 2020-12-31    10806.579016
# 2021-12-31    13761.408893
# 2022-12-31     9876.274960
# 2023-12-31    12757.317073
# Freq: A-DEC, Name: Adj Close, dtype: float64

# %%
#now the standard deviation for all columns for each year, this shows the variation in the data

df.std()

yearly_std_summary = df_FLTR.resample('Y').std()

print(yearly_std_summary)
# Out:
#                    Open         High          Low        Close    Adj Close         Volume     Month  Close_by_Month
# Date
# 2018-12-31   791.464152   791.467499   798.853364   796.081833   707.356794  180483.693295  3.442983      536.371095
# 2019-12-31   979.320794   987.653781   977.037426   979.321562  1011.880937  421665.969934  3.451001      538.871947
# 2020-12-31  2278.855276  2280.340465  2273.284324  2279.711872  2326.199719  461312.547411  3.461452      539.366739
# 2021-12-31  1498.525795  1538.529371  1477.625581  1495.222831  1495.222831  388460.439009  3.445897      540.697305
# 2022-12-31  1470.707044  1472.844662  1463.305704  1465.326795  1465.326795  365731.503393  3.445605      540.452660
# 2023-12-31   611.043041   571.832670   554.172064   580.049672   580.049672  576714.163205  0.506061       41.467051

# %%
#this is showing the max figure for the selected columns

df.loc[:,['Close', 'Volume']].max()
# Out:
# Close       16915.0
# Volume    5769086.0
# dtype: float64

# %%
#create a column to show if the stock is tranding up or down each day based on the previous day's close

# assuming your DataFrame is called 'df' and the containing closing prices is called 'close'

#df_FLTR['Trend'] = df_FLTR['Adj Close'].apply(lambda x: 'Up' if x > df_FLTR['Adj Close'].shift(1) else 'down')
import numpy as np

df_FLTR['Trend'] = np.where(df_FLTR['Low'] > df_FLTR['Low'].shift(1), 'Up', 'Down')

print(df_FLTR)

# %%
### NUMPY ####

#data = np.loadtxt(filename, delimiter =',', skiprows = 1)

# convert the date column to numpy datetime objects
#df['Date'] = np.array(df['Date'], dtype=np.datetime64)

# Convert the date column to a numerical format, this will help with any NumPy queries
#df['Date'] = pd.to_datetime(df['Date'])

arr_FLTR = df_FLTR.values #this converts the  to convert it to NumPy and a 2D array 

# Print the type and shape of the ndarray

print(type(arr_FLTR))
(arr_FLTR.shape)


#data_FLTR_np = data.to_numpy()
# Out:
# <class 'numpy.ndarray'>
# (1304, 6)

# %%
#date column
arr_FLTR = arr_FLTR[:, 1:]

# %%
print(arr_FLTR)
# Out:
# []

# %%
import datetime

# Date and time now
now = datetime.datetime.now()
print(now)

# Stars Group Merger - Date that the market was made aware of a large merger between Paddy Power Betfair and the Satrs Group (both are now identified under parent company 'Flutter')
stars_merger = datetime.datetime(2019, 10, 2)
print(stars_merger)

print(df_FLTR.loc[stars_merger,:]) #use the loc method to find the stock prices on this important day
# Out:
# 2023-03-20 15:09:59.878041
# 2019-10-02 00:00:00
# Open         8.753338e+03
# High         9.123142e+03
# Low          7.830795e+03
# Close        8.029466e+03
# Adj Close    7.886559e+03
# Volume       5.538550e+06
# Name: 2019-10-02 00:00:00, dtype: float64

# %%
df_FLTR.count()
# Out:
# Open         1304
# High         1304
# Low          1304
# Close        1304
# Adj Close    1304
# Volume       1304
# dtype: int64

# %%
df_FLTR.loc[:, 'Low'] #demo of using the loc feature to access rows and/or columns by name
# Out:
# Date
# 2018-01-02     8654.985352
# 2018-01-03     8620.562500
# 2018-01-04     8536.962891
# 2018-01-05     8630.397461
# 2018-01-08     8492.705078
#                   ...
# 2023-02-22    13625.000000
# 2023-02-23    13580.000000
# 2023-02-24    13035.000000
# 2023-02-27    13110.000000
# 2023-02-28    13250.000000
# Name: Low, Length: 1304, dtype: float64

# %%
df_FLTR.loc[:, 'Low'] >9000 #shows a boolean value for each row where the LOW for the day was not above 9000
# Out:
# Date
# 2018-01-02    False
# 2018-01-03    False
# 2018-01-04    False
# 2018-01-05    False
# 2018-01-08    False
#               ...
# 2023-02-22     True
# 2023-02-23     True
# 2023-02-24     True
# 2023-02-27     True
# 2023-02-28     True
# Name: Low, Length: 1304, dtype: bool

# %%
#I will now read in a further dataset and compare this (Entain and Flutter) 

# Read the CSV file
df_ENT = pd.read_csv('ENT.L.csv', parse_dates=['Date'], index_col='Date')

# %%
df_ENT.head()
# Out:
#              Open   High    Low  Close   Adj Close   Volume
# Date
# 2018-01-02  942.0  948.5  928.0  944.5  824.535156  1738754
# 2018-01-03  945.0  970.0  940.0  962.5  840.248901  2149160
# 2018-01-04  965.5  982.0  956.0  982.0  857.272095  1850266
# 2018-01-05  977.0  990.5  964.5  968.5  845.486816  2099451
# 2018-01-08  974.0  974.5  946.0  953.5  832.392029   972158

# %%
df_ENT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1304 entries, 2018-01-02 to 2023-02-28
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1304 non-null   float64
#  1   High       1304 non-null   float64
#  2   Low        1304 non-null   float64
#  3   Close      1304 non-null   float64
#  4   Adj Close  1304 non-null   float64
#  5   Volume     1304 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 71.3 KB

# %%
print(df_ENT.index.min())
print(df_ENT.index.max())
# Out:
# 2018-01-02 00:00:00
# 2023-02-28 00:00:00

# %%
plt.plot(df_FLTR.index, df_FLTR['Close'], label='Flutter') #this shows us general trends but is not ideal as the two stocks start at different places
plt.plot(df_ENT.index, df_ENT['Close'], label='Entain')
plt.legend()
plt.show()

# %%
# I will try to normalize the data by dividing each value by the first value in the series, this should ensure that both stocks start at the same place
df_FLTR_norm = df_FLTR['Close'] / df_FLTR['Close'].iloc[0]
df_ENT_norm = df_ENT['Close'] / df_ENT['Close'].iloc[0]

# %%
# Line plot comparison with the normalised data
plt.plot(df_FLTR_norm, label='Flutter Stock')
plt.plot(df_ENT_norm, label='Entain Stock')
plt.xlabel('Time')
plt.ylabel('Normalized Stock Price')
plt.title('Line Plot of Normalized Stock Prices')
plt.legend()
plt.show()

# %%
# !pip install seaborn
import seaborn as sns
# Out:
# Requirement already satisfied: seaborn in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=0.25 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: cycler>=0.10 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: zipp>=3.1.0 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/markherbert/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
# Scatter plot comparison with normalised data
plt.scatter(df_FLTR_norm, df_ENT_norm)
plt.xlabel('Flutter Price')
plt.ylabel('Entain Price')
plt.title('Scatter Plot of Flutter & Entain Stock Prices')
plt.show()

# %%
plt.fill_between(df_FLTR.index, df_FLTR_norm, df_ENT_norm, where=df_FLTR_norm > df_ENT_norm, interpolate=True, alpha=0.5)
plt.fill_between(df_FLTR.index, df_ENT_norm, df_FLTR_norm, where=df_FLTR_norm < df_ENT_norm, interpolate=True, alpha=0.5)
plt.xlabel('Time')
plt.ylabel('Normalized Stock Price')
plt.title('Area Plot of Normalized Stock Prices')
plt.show()

# %%
#summary statistics for the stocks 
summary = pd.DataFrame({
    'Flutter_mean': df_FLTR.mean(),
    'Entain_mean': df_ENT.mean(),
    'Flutter_std': df_FLTR.std(),
    'Entain_std': df_ENT.std()
})
summary
# Out:
#             Flutter_mean   Entain_mean    Flutter_std    Entain_std
# Open         9829.233115  1.126320e+03    2941.855284  4.187289e+02
# High         9981.695741  1.145041e+03    2988.818444  4.242993e+02
# Low          9677.147565  1.106718e+03    2893.998009  4.136769e+02
# Close        9826.217119  1.126233e+03    2934.870495  4.187261e+02
# Adj Close    9694.440091  1.086956e+03    3050.111673  4.295256e+02
# Volume     450939.628067  3.219966e+06  407640.405512  3.547235e+06

# %%
#Plotting the volume of Flutter and Entain on two lines
plt.plot(df_FLTR.index, df_FLTR['Volume'], color='red')
plt.plot(df_FLTR.index, df_ENT['Volume'], color='blue')

#  labels
plt.xlabel('Days')
plt.ylabel('Volume, #')
plt.title('Volume Comparison between Flutter & Entain')
plt.show()

# %%
plt.hist(df_FLTR[x=Volume, bins = 6, density=1)] # I plyaed around with the bindwidth here but count was a much better identifier than frequency(%)
plt.hist(df_ENT[x=Volume, bins = 6, density=1)] 
plt.xlabel('Time')
plt.ylabel('Count')
plt.show()
# Out:
#   Cell In[180], line 1
#     plt.hist(df_FLTR[x=Volume, bins = 6, density=1)] # I plyaed around with the bindwidth here but count was a much better identifier than frequency(%)
#                       ^
# SyntaxError: invalid syntax

# %%
plt.hist(df_FLTR['Close'], bins=200, density=1) # Use square brackets to access a column in a dataframe
plt.hist(df_ENT['Close'], bins=200, density=1) 
plt.xlabel('Time')
plt.ylabel('Count')
plt.show()

# %%
sns.scatterplot(data=data, x="x_column", y="y_column", hue="group_column")
